# %% [markdown]
# ## PROJECT 36: Forecasting energy consumption for train traction
#
# > ### TASK: To study various modern approaches and models to forecasting power consumption for train traction
#
#
# ### Stage goal
#
# - **Create Naïve forecasting like baseline model**
# - **Apply N-BEATS model for forecasting power consumption for train traction**
# -**Compare results**

# %% [markdown]
# ### IMPORT LIBRARIES

# %%
# !pip install -U statsmodels

# !pip install sktime

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# plt.style.use('bmh')
import seaborn as sns
sns.set_style('darkgrid')

import statsmodels.api as sm

from sktime.forecasting.naive import NaiveForecaster
from sktime.performance_metrics.forecasting import MeanAbsoluteError, MeanSquaredError, MeanAbsolutePercentageError, MeanAbsoluteScaledError
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.model_selection import temporal_train_test_split



from sklearn.preprocessing import MinMaxScaler

from pandas import DataFrame
from pandas import concat

import tensorflow as tf
from tensorflow.keras.layers import Conv1D, Dropout, Dense, Input,  MaxPool1D, subtract, add
from tensorflow.keras.models import Model

# %% [markdown]
# ### DATA PREPARATON

# %%
# Path to data
data_path ="/content/drive/MyDrive/Project_36_Forecasting_energy_consumption_for_train_traction/data/Raskhod_EP_24_03_2020.csv"

# %%
# Load the data
data_df = pd.read_csv(data_path, sep=';')

# %%
# Dictionary of variables
list_of_variables = {'Ввод подстанции' : 'entering_substation',
                     'Date' : 'date',
                     'Расход' : 'consumption',
                     'Макс.' : 'max_consumption'}   

# Re-assign variables
data_df = data_df.rename(columns = list_of_variables) 

data_df['date'] = pd.to_datetime(data_df['date'])

# Creating a multi-index
data_df = data_df.set_index(['date','entering_substation'])

# List of traction substations
data_df.index.levels[1].to_list()
# Out:
# ['Бада - Ввод Т1 27.5 кВ',
#  'Бада - Ввод Т2 27.5 кВ',
#  'Белогорск - Ввод Т1 27.5 кВ',
#  'Белогорск - Ввод Т2 27.5 кВ',
#  'Бушулей - Ввод Т1 27.5 кВ',
#  'Бушулей - Ввод Т2 27.5 кВ',
#  'Завитая - Ввод Т1 27.5 кВ',
#  'Завитая - Ввод Т2 27.5 кВ',
#  'Зилово - Ввод Т1 27.5 кВ',
#  'Зилово - Ввод Т3 27.5 кВ',
#  'Карымская - Ввод Т1 27.5 кВ',
#  'Карымская - Ввод Т2 27.5 кВ',
#  'Карымская - Ввод Т6 27.5 кВ',
#  'Магдагачи - Ввод Т1 27.5 кВ',
#  'Магдагачи - Ввод Т2 27.5 кВ',
#  'Могзон - Ввод Т1 27.5 кВ',
#  'Могзон - Ввод Т2 27.5 кВ',
#  'Могоча - Ввод Т1 27.5 кВ',
#  'Могоча - Ввод Т2 27.5 кВ',
#  'Новая - Ввод Т1 27.5 кВ',
#  'Новая - Ввод Т2 27.5 кВ']

# %% [markdown]
# #### **As an example for further research and training of the model, we use the Belogorsk traction substation - Input T2 27.5 kV**

# %%
# Selection of traction substation
traction_substation_df = data_df.xs('Белогорск - Ввод Т2 27.5 кВ', level=1)['consumption']

# Removing duplicate values
traction_substation_df = traction_substation_df.drop_duplicates()

# Selection of the required subset of data
traction_substation_df = traction_substation_df.sort_index(level=[0]).loc['2017-01-01':'2019-12-31']

traction_substation_df.head()
# Out:
# date
# 2017-01-01    230640
# 2017-01-02    251133
# 2017-01-03    231118
# 2017-01-04    235054
# 2017-01-05    134475
# Name: consumption, dtype: int64

# %% [markdown]
# ### EVALUATION RESULT

# %%
# EVALUATION AND VISUALIZATION OF MODEL PARAMETERS
def learning_curves(history):
    pd.DataFrame(history.history).plot(figsize=(20, 8))
    plt.grid(True)
    plt.title('Learning curves')
    plt.gca().set_ylim(0, 1)
    plt.show()


def evaluation_model(history):
    fig, (axL, axR) = plt.subplots(ncols=2, figsize=(20, 8))
    axL.plot(history.history['loss'], label="Training loss")
    axL.plot(history.history['val_loss'], label="Validation loss")
    axL.set_title('Training and Validation loss')
    axL.set_xlabel('Epochs')
    axL.set_ylabel('Loss')
    axL.legend(loc='upper right')

    axR.plot(history.history['mae'], label="Training mae")
    axR.plot(history.history['val_mae'], label="Validation mae")
    axR.set_title('Training and Validation mae')
    axR.set_xlabel('Epoch')
    axR.set_ylabel('MAE')
    axR.legend(loc='upper right')

    plt.show()
    
def plot_time_series(timesteps, values, format='.', start=0, end=None, label=None):
    # Plot the series
    plt.plot(timesteps[start:end], values[start:end], format, label=label)
    plt.xlabel("Time")
    plt.ylabel("People")
    if label:
        plt.legend(fontsize=14) # make label bigger
    plt.grid(True)
    
def make_preds(model, input_data):
    forecast = model.predict(input_data)
    return tf.squeeze(forecast)


def mean_absolute_scaled_error(y_true, y_pred):
    mae = tf.reduce_mean(tf.abs(y_true - y_pred))
    # Find MAE of naive forecast (no seasonality)
    mae_naive_no_season = tf.reduce_mean(tf.abs(y_true[1:] - y_true[:-1])) # our seasonality is 1 day (hence the shifting of 1 day)

    return mae / mae_naive_no_season


def evaluate_preds(y_true, y_pred):
    # Make sure float32 (for metric calculations)
    y_true = tf.cast(y_true, dtype=tf.float32)
    y_pred = tf.cast(y_pred, dtype=tf.float32)

    # Calculate various metrics
    mae = tf.keras.metrics.mean_absolute_error(y_true, y_pred)
    mse = tf.keras.metrics.mean_squared_error(y_true, y_pred) # puts and emphasis on outliers (all errors get squared)
    rmse = tf.sqrt(mse)
    mape = tf.keras.metrics.mean_absolute_percentage_error(y_true, y_pred)
    mase = mean_absolute_scaled_error(y_true, y_pred)
  
    return {"mae": mae.numpy(),
            "mse": mse.numpy(),
            "rmse": rmse.numpy(),
            "mape": mape.numpy(),
            "mase": mase.numpy()}

# %% [markdown]
# ### Naïve forecast (baseline) $\hat{y}_{t}=y_{t-1}$

# %%
def plot_time_series(timesteps, values, format='-', start=0, end=None, label=None):
  """
  Plots a timesteps (a series of points in time) against values (a series of values across timesteps).
  
  Parameters
  ---------
  timesteps : array of timesteps
  values : array of values across time
  format : style of plot, default "."
  start : where to start the plot (setting a value will index from start of timesteps & values)
  end : where to end the plot (setting a value will index from end of timesteps & values)
  label : label to show on plot of values
  """
  # Plot the series
  plt.plot(timesteps[start:end], values[start:end], format, label=label)
  plt.xlabel("Time")
  plt.ylabel("Consumption")
  if label:
    plt.legend(fontsize=14) # make label bigger
  plt.grid(True)

# %%
split_size = int(0.8 * len(traction_substation_df)) 

timesteps = traction_substation_df.index.to_numpy()
consumption = traction_substation_df[:].to_numpy()

X_train, y_train = timesteps[:split_size], consumption[:split_size]

X_test, y_test = timesteps[split_size:], consumption[split_size:]

len(X_train), len(X_test), len(y_train), len(y_test)
# Out:
# (846, 212, 846, 212)

# %%
# Naïve forecast
naive_forecast = y_test[:-1]

# %%
# Plot naive forecast
aa=[x for x in range(211)]
plt.figure(figsize=(25, 5))
plt.plot(aa, y_test[:211], marker='.', label="actual")
plt.plot(aa, naive_forecast[:211], 'r', label="prediction")
plt.ylabel('Consumption', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# %%
naive_results = evaluate_preds(y_true=y_test[1:],
                               y_pred=naive_forecast)
naive_results
# Out:
# {'mae': 31373.07,
#  'mape': 16.718054,
#  'mase': 0.9957199,
#  'mse': 1794750500.0,
#  'rmse': 42364.496}

# %% [markdown]
# ## N-BEATS model

# %% [markdown]
# Transform the data into a time series problem

# %%
def series_to_supervised(data, n_in=7, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
values = traction_substation_df.values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values.reshape(-1, 1))

data_df_norm = series_to_supervised(scaled, n_in=7, n_out=1, dropnan=True)
data_df_norm.head()
# Out:
#     var1(t-7)  var1(t-6)  var1(t-5)  ...  var1(t-2)  var1(t-1)   var1(t)
# 7    0.757882   0.844805   0.759909  ...   0.443572   0.402119  0.604680
# 8    0.844805   0.759909   0.776604  ...   0.402119   0.604680  0.617337
# 9    0.759909   0.776604   0.349990  ...   0.604680   0.617337  0.801388
# 10   0.776604   0.349990   0.443572  ...   0.617337   0.801388  0.498441
# 11   0.349990   0.443572   0.402119  ...   0.801388   0.498441  0.625875
#
# [5 rows x 8 columns]

# %%
values = data_df_norm.values

n_train_time = int(len(traction_substation_df)*0.8)

train = values[:n_train_time, :]
test = values[n_train_time:, :]

X_train, y_train = train[:, :-1], train[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((846, 7), (205, 7), (846,), (205,))

# %% [markdown]
# ### Create NBeatsBlock custom layer

# %%
class NBeatsBlock(tf.keras.layers.Layer):
  def __init__(self,
               input_size: int,
               theta_size: int,
               horizon: int,
               n_neurons: int,
               n_layers: int,
               **kwargs):
    super().__init__(**kwargs)
    self.input_size = input_size
    self.theta_size = theta_size
    self.horizon = horizon
    self.n_neurons = n_neurons
    self.n_layers = n_layers

    # Stack of 4 fully connected layers each has ReLU activation
    self.hidden = [tf.keras.layers.Dense(n_neurons, activation="relu") for _ in range(n_layers)]

    # Output of block is a theta layer
    self.theta_layer = tf.keras.layers.Dense(theta_size, activation="linear", name="theta")

  def call(self, inputs):
    x = inputs
    for layer in self.hidden:
      x = layer(x)
    theta = self.theta_layer(x)

    # Output the backcast and forecast from theta
    backcast, forecast = theta[:, :self.input_size], theta[:, -self.horizon:]
    return backcast, forecast

# %% [markdown]
# ### Prepare data with `tf.data`

# %%
# 1. Turn train and test arrays into tensor Datasets
train_features_dataset = tf.data.Dataset.from_tensor_slices(X_train)
train_labels_dataset = tf.data.Dataset.from_tensor_slices(y_train)

test_features_dataset = tf.data.Dataset.from_tensor_slices(X_test)
test_labels_dataset = tf.data.Dataset.from_tensor_slices(y_test)

# 2. Combine features & labels
train_dataset = tf.data.Dataset.zip((train_features_dataset, train_labels_dataset))
test_dataset = tf.data.Dataset.zip((test_features_dataset, test_labels_dataset))

# 3. Batch and prefetch for optimal performance
BATCH_SIZE = 1024 # taken from Appendix D in N-BEATS paper

train_dataset = train_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)
test_dataset = test_dataset.batch(BATCH_SIZE).prefetch(tf.data.AUTOTUNE)

train_dataset, test_dataset
# Out:
# (<PrefetchDataset shapes: ((None, 7), (None,)), types: (tf.float64, tf.float64)>,
#  <PrefetchDataset shapes: ((None, 7), (None,)), types: (tf.float64, tf.float64)>)

# %% [markdown]
# ### Setting up hyperparameters for N-BEATS algorithm

# %%
# Values from N-BEATS paper Figure 1 and Table 18/Appendix D
N_EPOCHS = 5000 # called "Iterations" in Table 18
N_NEURONS = 512 # called "Width" in Table 18
N_LAYERS = 4
N_STACKS = 30

HORIZON = 1 
WINDOW_SIZE = 7

INPUT_SIZE = WINDOW_SIZE * HORIZON # called "Lookback" in Table 18
THETA_SIZE = INPUT_SIZE + HORIZON

INPUT_SIZE, THETA_SIZE
# Out:
# (7, 8)

# %% [markdown]
# ### N-BEATS

# %%
# 1. Setup N-BEATS Block layer
nbeats_block_layer = NBeatsBlock(input_size=INPUT_SIZE,
                                 theta_size=THETA_SIZE,
                                 horizon=HORIZON,
                                 n_neurons=N_NEURONS,
                                 n_layers=N_LAYERS,
                                 name="InitialBlock")

# 2. Create input to stacks
stack_input = Input(shape=(INPUT_SIZE), name="stack_input")

# 3. Create initial backcast and forecast input (backwards predictions are referred to as residuals in the paper)
backcast, forecast = nbeats_block_layer(stack_input)

# Add in subtraction residual link
residuals = subtract([stack_input, backcast], name=f"subtract_00") 

# 4. Create stacks of blocks
for i, _ in enumerate(range(N_STACKS-1)): # first stack is already creted in (3)

  # 5. Use the NBeatsBlock to calculate the backcast as well as block forecast
  backcast, block_forecast = NBeatsBlock(
      input_size=INPUT_SIZE,
      theta_size=THETA_SIZE,
      horizon=HORIZON,
      n_neurons=N_NEURONS,
      n_layers=N_LAYERS,
      name=f"NBeatsBlock_{i}")(residuals) # pass it in residuals (the backcast)

  # 6. Create the double residual stacking
  residuals = subtract([residuals, backcast], name=f"subtract_{i}") 
  forecast = add([forecast, block_forecast], name=f"add_{i}")

# 7. Put the stack model together
model_N_BEATS = tf.keras.Model(inputs=stack_input, 
                         outputs=forecast, 
                         name="model_N-BEATS")

# %%
# Compile model
model_N_BEATS.compile(loss="mae",
                      optimizer=tf.keras.optimizers.Adam(0.001),
                      metrics=["mae", "mse"])

# %%
model_N_BEATS.summary()
tf.keras.utils.plot_model(model_N_BEATS, to_file='model_N_BEATS.png')
# Out:
# Model: "model_N-BEATS"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  stack_input (InputLayer)       [(None, 7)]          0           []
#
#  InitialBlock (NBeatsBlock)     ((None, 7),          796168      ['stack_input[0][0]']
#                                  (None, 1))
#
#  subtract_00 (Subtract)         (None, 7)            0           ['stack_input[0][0]',
#                                                                   'InitialBlock[0][0]']
#
#  NBeatsBlock_0 (NBeatsBlock)    ((None, 7),          796168      ['subtract_00[0][0]']
#                                  (None, 1))
#
#  subtract_0 (Subtract)          (None, 7)            0           ['subtract_00[0][0]',
#                                                                   'NBeatsBlock_0[0][0]']
#
#  NBeatsBlock_1 (NBeatsBlock)    ((None, 7),          796168      ['subtract_0[0][0]']
#                                  (None, 1))
#
#  subtract_1 (Subtract)          (None, 7)            0           ['subtract_0[0][0]',
#                                                                   'NBeatsBlock_1[0][0]']
#
#  NBeatsBlock_2 (NBeatsBlock)    ((None, 7),          796168      ['subtract_1[0][0]']
#                                  (None, 1))
#
#  subtract_2 (Subtract)          (None, 7)            0           ['subtract_1[0][0]',
#                                                                   'NBeatsBlock_2[0][0]']
#
#  NBeatsBlock_3 (NBeatsBlock)    ((None, 7),          796168      ['subtract_2[0][0]']
#                                  (None, 1))
#
#  subtract_3 (Subtract)          (None, 7)            0           ['subtract_2[0][0]',
#                                                                   'NBeatsBlock_3[0][0]']
#
#  NBeatsBlock_4 (NBeatsBlock)    ((None, 7),          796168      ['subtract_3[0][0]']
#                                  (None, 1))
#
#  subtract_4 (Subtract)          (None, 7)            0           ['subtract_3[0][0]',
#                                                                   'NBeatsBlock_4[0][0]']
#
#  NBeatsBlock_5 (NBeatsBlock)    ((None, 7),          796168      ['subtract_4[0][0]']
#                                  (None, 1))
#
#  subtract_5 (Subtract)          (None, 7)            0           ['subtract_4[0][0]',
#                                                                   'NBeatsBlock_5[0][0]']
#
#  NBeatsBlock_6 (NBeatsBlock)    ((None, 7),          796168      ['subtract_5[0][0]']
#                                  (None, 1))
#
#  subtract_6 (Subtract)          (None, 7)            0           ['subtract_5[0][0]',
#                                                                   'NBeatsBlock_6[0][0]']
#
#  NBeatsBlock_7 (NBeatsBlock)    ((None, 7),          796168      ['subtract_6[0][0]']
#                                  (None, 1))
#
#  subtract_7 (Subtract)          (None, 7)            0           ['subtract_6[0][0]',
#                                                                   'NBeatsBlock_7[0][0]']
#
#  NBeatsBlock_8 (NBeatsBlock)    ((None, 7),          796168      ['subtract_7[0][0]']
#                                  (None, 1))
#
#  subtract_8 (Subtract)          (None, 7)            0           ['subtract_7[0][0]',
#                                                                   'NBeatsBlock_8[0][0]']
#
#  NBeatsBlock_9 (NBeatsBlock)    ((None, 7),          796168      ['subtract_8[0][0]']
#                                  (None, 1))
#
#  subtract_9 (Subtract)          (None, 7)            0           ['subtract_8[0][0]',
#                                                                   'NBeatsBlock_9[0][0]']
#
#  NBeatsBlock_10 (NBeatsBlock)   ((None, 7),          796168      ['subtract_9[0][0]']
#                                  (None, 1))
#
#  subtract_10 (Subtract)         (None, 7)            0           ['subtract_9[0][0]',
#                                                                   'NBeatsBlock_10[0][0]']
#
#  NBeatsBlock_11 (NBeatsBlock)   ((None, 7),          796168      ['subtract_10[0][0]']
#                                  (None, 1))
#
#  subtract_11 (Subtract)         (None, 7)            0           ['subtract_10[0][0]',
#                                                                   'NBeatsBlock_11[0][0]']
#
#  NBeatsBlock_12 (NBeatsBlock)   ((None, 7),          796168      ['subtract_11[0][0]']
#                                  (None, 1))
#
#  subtract_12 (Subtract)         (None, 7)            0           ['subtract_11[0][0]',
#                                                                   'NBeatsBlock_12[0][0]']
#
#  NBeatsBlock_13 (NBeatsBlock)   ((None, 7),          796168      ['subtract_12[0][0]']
#                                  (None, 1))
#
#  subtract_13 (Subtract)         (None, 7)            0           ['subtract_12[0][0]',
#                                                                   'NBeatsBlock_13[0][0]']
#
#  NBeatsBlock_14 (NBeatsBlock)   ((None, 7),          796168      ['subtract_13[0][0]']
#                                  (None, 1))
#
#  add_0 (Add)                    (None, 1)            0           ['InitialBlock[0][1]',
#                                                                   'NBeatsBlock_0[0][1]']
#
#  subtract_14 (Subtract)         (None, 7)            0           ['subtract_13[0][0]',
#                                                                   'NBeatsBlock_14[0][0]']
#
#  add_1 (Add)                    (None, 1)            0           ['add_0[0][0]',
#                                                                   'NBeatsBlock_1[0][1]']
#
#  NBeatsBlock_15 (NBeatsBlock)   ((None, 7),          796168      ['subtract_14[0][0]']
#                                  (None, 1))
#
#  add_2 (Add)                    (None, 1)            0           ['add_1[0][0]',
#                                                                   'NBeatsBlock_2[0][1]']
#
#  subtract_15 (Subtract)         (None, 7)            0           ['subtract_14[0][0]',
#                                                                   'NBeatsBlock_15[0][0]']
#
#  add_3 (Add)                    (None, 1)            0           ['add_2[0][0]',
#                                                                   'NBeatsBlock_3[0][1]']
#
#  NBeatsBlock_16 (NBeatsBlock)   ((None, 7),          796168      ['subtract_15[0][0]']
#                                  (None, 1))
#
#  add_4 (Add)                    (None, 1)            0           ['add_3[0][0]',
#                                                                   'NBeatsBlock_4[0][1]']
#
#  subtract_16 (Subtract)         (None, 7)            0           ['subtract_15[0][0]',
#                                                                   'NBeatsBlock_16[0][0]']
#
#  add_5 (Add)                    (None, 1)            0           ['add_4[0][0]',
#                                                                   'NBeatsBlock_5[0][1]']
#
#  NBeatsBlock_17 (NBeatsBlock)   ((None, 7),          796168      ['subtract_16[0][0]']
#                                  (None, 1))
#
#  add_6 (Add)                    (None, 1)            0           ['add_5[0][0]',
#                                                                   'NBeatsBlock_6[0][1]']
#
#  subtract_17 (Subtract)         (None, 7)            0           ['subtract_16[0][0]',
#                                                                   'NBeatsBlock_17[0][0]']
#
#  add_7 (Add)                    (None, 1)            0           ['add_6[0][0]',
#                                                                   'NBeatsBlock_7[0][1]']
#
#  NBeatsBlock_18 (NBeatsBlock)   ((None, 7),          796168      ['subtract_17[0][0]']
#                                  (None, 1))
#
#  add_8 (Add)                    (None, 1)            0           ['add_7[0][0]',
#                                                                   'NBeatsBlock_8[0][1]']
#
#  subtract_18 (Subtract)         (None, 7)            0           ['subtract_17[0][0]',
#                                                                   'NBeatsBlock_18[0][0]']
#
#  add_9 (Add)                    (None, 1)            0           ['add_8[0][0]',
#                                                                   'NBeatsBlock_9[0][1]']
#
#  NBeatsBlock_19 (NBeatsBlock)   ((None, 7),          796168      ['subtract_18[0][0]']
#                                  (None, 1))
#
#  add_10 (Add)                   (None, 1)            0           ['add_9[0][0]',
#                                                                   'NBeatsBlock_10[0][1]']
#
#  subtract_19 (Subtract)         (None, 7)            0           ['subtract_18[0][0]',
#                                                                   'NBeatsBlock_19[0][0]']
#
#  add_11 (Add)                   (None, 1)            0           ['add_10[0][0]',
#                                                                   'NBeatsBlock_11[0][1]']
#
#  NBeatsBlock_20 (NBeatsBlock)   ((None, 7),          796168      ['subtract_19[0][0]']
#                                  (None, 1))
#
#  add_12 (Add)                   (None, 1)            0           ['add_11[0][0]',
#                                                                   'NBeatsBlock_12[0][1]']
#
#  subtract_20 (Subtract)         (None, 7)            0           ['subtract_19[0][0]',
#                                                                   'NBeatsBlock_20[0][0]']
#
#  add_13 (Add)                   (None, 1)            0           ['add_12[0][0]',
#                                                                   'NBeatsBlock_13[0][1]']
#
#  NBeatsBlock_21 (NBeatsBlock)   ((None, 7),          796168      ['subtract_20[0][0]']
#                                  (None, 1))
#
#  add_14 (Add)                   (None, 1)            0           ['add_13[0][0]',
#                                                                   'NBeatsBlock_14[0][1]']
#
#  subtract_21 (Subtract)         (None, 7)            0           ['subtract_20[0][0]',
#                                                                   'NBeatsBlock_21[0][0]']
#
#  add_15 (Add)                   (None, 1)            0           ['add_14[0][0]',
#                                                                   'NBeatsBlock_15[0][1]']
#
#  NBeatsBlock_22 (NBeatsBlock)   ((None, 7),          796168      ['subtract_21[0][0]']
#                                  (None, 1))
#
#  add_16 (Add)                   (None, 1)            0           ['add_15[0][0]',
#                                                                   'NBeatsBlock_16[0][1]']
#
#  subtract_22 (Subtract)         (None, 7)            0           ['subtract_21[0][0]',
#                                                                   'NBeatsBlock_22[0][0]']
#
#  add_17 (Add)                   (None, 1)            0           ['add_16[0][0]',
#                                                                   'NBeatsBlock_17[0][1]']
#
#  NBeatsBlock_23 (NBeatsBlock)   ((None, 7),          796168      ['subtract_22[0][0]']
#                                  (None, 1))
#
#  add_18 (Add)                   (None, 1)            0           ['add_17[0][0]',
#                                                                   'NBeatsBlock_18[0][1]']
#
#  subtract_23 (Subtract)         (None, 7)            0           ['subtract_22[0][0]',
#                                                                   'NBeatsBlock_23[0][0]']
#
#  add_19 (Add)                   (None, 1)            0           ['add_18[0][0]',
#                                                                   'NBeatsBlock_19[0][1]']
#
#  NBeatsBlock_24 (NBeatsBlock)   ((None, 7),          796168      ['subtract_23[0][0]']
#                                  (None, 1))
#
#  add_20 (Add)                   (None, 1)            0           ['add_19[0][0]',
#                                                                   'NBeatsBlock_20[0][1]']
#
#  subtract_24 (Subtract)         (None, 7)            0           ['subtract_23[0][0]',
#                                                                   'NBeatsBlock_24[0][0]']
#
#  add_21 (Add)                   (None, 1)            0           ['add_20[0][0]',
#                                                                   'NBeatsBlock_21[0][1]']
#
#  NBeatsBlock_25 (NBeatsBlock)   ((None, 7),          796168      ['subtract_24[0][0]']
#                                  (None, 1))
#
#  add_22 (Add)                   (None, 1)            0           ['add_21[0][0]',
#                                                                   'NBeatsBlock_22[0][1]']
#
#  subtract_25 (Subtract)         (None, 7)            0           ['subtract_24[0][0]',
#                                                                   'NBeatsBlock_25[0][0]']
#
#  add_23 (Add)                   (None, 1)            0           ['add_22[0][0]',
#                                                                   'NBeatsBlock_23[0][1]']
#
#  NBeatsBlock_26 (NBeatsBlock)   ((None, 7),          796168      ['subtract_25[0][0]']
#                                  (None, 1))
#
#  add_24 (Add)                   (None, 1)            0           ['add_23[0][0]',
#                                                                   'NBeatsBlock_24[0][1]']
#
#  subtract_26 (Subtract)         (None, 7)            0           ['subtract_25[0][0]',
#                                                                   'NBeatsBlock_26[0][0]']
#
#  add_25 (Add)                   (None, 1)            0           ['add_24[0][0]',
#                                                                   'NBeatsBlock_25[0][1]']
#
#  NBeatsBlock_27 (NBeatsBlock)   ((None, 7),          796168      ['subtract_26[0][0]']
#                                  (None, 1))
#
#  add_26 (Add)                   (None, 1)            0           ['add_25[0][0]',
#                                                                   'NBeatsBlock_26[0][1]']
#
#  subtract_27 (Subtract)         (None, 7)            0           ['subtract_26[0][0]',
#                                                                   'NBeatsBlock_27[0][0]']
#
#  add_27 (Add)                   (None, 1)            0           ['add_26[0][0]',
#                                                                   'NBeatsBlock_27[0][1]']
#
#  NBeatsBlock_28 (NBeatsBlock)   ((None, 7),          796168      ['subtract_27[0][0]']
#                                  (None, 1))
#
#  add_28 (Add)                   (None, 1)            0           ['add_27[0][0]',
#                                                                   'NBeatsBlock_28[0][1]']
#
# ==================================================================================================
# Total params: 23,885,040
# Trainable params: 23,885,040
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Fit the model with EarlyStopping and ReduceLROnPlateau callbacks
model_N_BEATS_history = model_N_BEATS.fit(train_dataset,
                                       epochs=N_EPOCHS,
                                       validation_data=test_dataset,
                                       verbose=2,
                                       callbacks=[tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=200, restore_best_weights=True),
                                       tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=100, verbose=1)])
# Out:
# Epoch 1/5000
# 1/1 - 15s - loss: 0.7455 - mae: 0.7455 - mse: 0.6019 - val_loss: 9.5766 - val_mae: 9.5766 - val_mse: 94.0193 - lr: 0.0010 - 15s/epoch - 15s/step
# Epoch 2/5000
# 1/1 - 3s - loss: 8.2397 - mae: 8.2397 - mse: 71.1303 - val_loss: 3.8301 - val_mae: 3.8301 - val_mse: 15.1928 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 3/5000
# 1/1 - 3s - loss: 3.6580 - mae: 3.6580 - mse: 14.1356 - val_loss: 1.2533 - val_mae: 1.2533 - val_mse: 1.6509 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 4/5000
# 1/1 - 3s - loss: 1.2230 - mae: 1.2230 - mse: 1.6219 - val_loss: 0.7978 - val_mae: 0.7978 - val_mse: 0.7419 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 5/5000
# 1/1 - 3s - loss: 0.9534 - mae: 0.9534 - mse: 1.0414 - val_loss: 0.2347 - val_mae: 0.2347 - val_mse: 0.0786 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 6/5000
# 1/1 - 3s - loss: 0.2792 - mae: 0.2792 - mse: 0.1076 - val_loss: 0.1697 - val_mae: 0.1697 - val_mse: 0.0432 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 7/5000
# 1/1 - 3s - loss: 0.1747 - mae: 0.1747 - mse: 0.0481 - val_loss: 0.1370 - val_mae: 0.1370 - val_mse: 0.0317 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 8/5000
# 1/1 - 3s - loss: 0.1539 - mae: 0.1539 - mse: 0.0399 - val_loss: 0.1789 - val_mae: 0.1789 - val_mse: 0.0448 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 9/5000
# 1/1 - 3s - loss: 0.1884 - mae: 0.1884 - mse: 0.0531 - val_loss: 0.1242 - val_mae: 0.1242 - val_mse: 0.0247 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 10/5000
# 1/1 - 2s - loss: 0.1391 - mae: 0.1391 - mse: 0.0322 - val_loss: 0.1884 - val_mae: 0.1884 - val_mse: 0.0506 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 11/5000
# 1/1 - 3s - loss: 0.1955 - mae: 0.1955 - mse: 0.0569 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 12/5000
# 1/1 - 3s - loss: 0.1308 - mae: 0.1308 - mse: 0.0293 - val_loss: 0.1823 - val_mae: 0.1823 - val_mse: 0.0475 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 13/5000
# 1/1 - 3s - loss: 0.1880 - mae: 0.1880 - mse: 0.0526 - val_loss: 0.1208 - val_mae: 0.1208 - val_mse: 0.0240 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 14/5000
# 1/1 - 3s - loss: 0.1308 - mae: 0.1308 - mse: 0.0293 - val_loss: 0.1599 - val_mae: 0.1599 - val_mse: 0.0387 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 15/5000
# 1/1 - 2s - loss: 0.1702 - mae: 0.1702 - mse: 0.0440 - val_loss: 0.1348 - val_mae: 0.1348 - val_mse: 0.0296 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 16/5000
# 1/1 - 3s - loss: 0.1477 - mae: 0.1477 - mse: 0.0349 - val_loss: 0.1338 - val_mae: 0.1338 - val_mse: 0.0280 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 17/5000
# 1/1 - 3s - loss: 0.1401 - mae: 0.1401 - mse: 0.0328 - val_loss: 0.1505 - val_mae: 0.1505 - val_mse: 0.0346 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 18/5000
# 1/1 - 3s - loss: 0.1553 - mae: 0.1553 - mse: 0.0390 - val_loss: 0.1134 - val_mae: 0.1134 - val_mse: 0.0217 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 19/5000
# 1/1 - 3s - loss: 0.1220 - mae: 0.1220 - mse: 0.0262 - val_loss: 0.1301 - val_mae: 0.1301 - val_mse: 0.0280 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 20/5000
# 1/1 - 3s - loss: 0.1410 - mae: 0.1410 - mse: 0.0321 - val_loss: 0.1233 - val_mae: 0.1233 - val_mse: 0.0256 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 21/5000
# 1/1 - 3s - loss: 0.1331 - mae: 0.1331 - mse: 0.0294 - val_loss: 0.1167 - val_mae: 0.1167 - val_mse: 0.0234 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 22/5000
# 1/1 - 3s - loss: 0.1241 - mae: 0.1241 - mse: 0.0271 - val_loss: 0.1304 - val_mae: 0.1304 - val_mse: 0.0282 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 23/5000
# 1/1 - 3s - loss: 0.1377 - mae: 0.1377 - mse: 0.0317 - val_loss: 0.1120 - val_mae: 0.1120 - val_mse: 0.0219 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 24/5000
# 1/1 - 2s - loss: 0.1194 - mae: 0.1194 - mse: 0.0254 - val_loss: 0.1181 - val_mae: 0.1181 - val_mse: 0.0235 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 25/5000
# 1/1 - 3s - loss: 0.1269 - mae: 0.1269 - mse: 0.0273 - val_loss: 0.1172 - val_mae: 0.1172 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 26/5000
# 1/1 - 3s - loss: 0.1255 - mae: 0.1255 - mse: 0.0268 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0211 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 27/5000
# 1/1 - 2s - loss: 0.1169 - mae: 0.1169 - mse: 0.0245 - val_loss: 0.1210 - val_mae: 0.1210 - val_mse: 0.0247 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 28/5000
# 1/1 - 2s - loss: 0.1255 - mae: 0.1255 - mse: 0.0277 - val_loss: 0.1143 - val_mae: 0.1143 - val_mse: 0.0224 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 29/5000
# 1/1 - 3s - loss: 0.1180 - mae: 0.1180 - mse: 0.0251 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0213 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 30/5000
# 1/1 - 3s - loss: 0.1173 - mae: 0.1173 - mse: 0.0242 - val_loss: 0.1162 - val_mae: 0.1162 - val_mse: 0.0223 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 31/5000
# 1/1 - 2s - loss: 0.1205 - mae: 0.1205 - mse: 0.0251 - val_loss: 0.1127 - val_mae: 0.1127 - val_mse: 0.0215 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 32/5000
# 1/1 - 2s - loss: 0.1138 - mae: 0.1138 - mse: 0.0235 - val_loss: 0.1204 - val_mae: 0.1204 - val_mse: 0.0247 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 33/5000
# 1/1 - 3s - loss: 0.1199 - mae: 0.1199 - mse: 0.0260 - val_loss: 0.1141 - val_mae: 0.1141 - val_mse: 0.0222 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 34/5000
# 1/1 - 3s - loss: 0.1128 - mae: 0.1128 - mse: 0.0236 - val_loss: 0.1134 - val_mae: 0.1134 - val_mse: 0.0214 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 35/5000
# 1/1 - 3s - loss: 0.1137 - mae: 0.1137 - mse: 0.0232 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0213 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 36/5000
# 1/1 - 2s - loss: 0.1129 - mae: 0.1129 - mse: 0.0231 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0219 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 37/5000
# 1/1 - 3s - loss: 0.1109 - mae: 0.1109 - mse: 0.0231 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0225 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 38/5000
# 1/1 - 2s - loss: 0.1114 - mae: 0.1114 - mse: 0.0232 - val_loss: 0.1112 - val_mae: 0.1112 - val_mse: 0.0211 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 39/5000
# 1/1 - 2s - loss: 0.1078 - mae: 0.1078 - mse: 0.0219 - val_loss: 0.1123 - val_mae: 0.1123 - val_mse: 0.0214 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 40/5000
# 1/1 - 3s - loss: 0.1091 - mae: 0.1091 - mse: 0.0221 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0220 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 41/5000
# 1/1 - 3s - loss: 0.1064 - mae: 0.1064 - mse: 0.0217 - val_loss: 0.1152 - val_mae: 0.1152 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 42/5000
# 1/1 - 2s - loss: 0.1068 - mae: 0.1068 - mse: 0.0220 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0215 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 43/5000
# 1/1 - 3s - loss: 0.1040 - mae: 0.1040 - mse: 0.0210 - val_loss: 0.1121 - val_mae: 0.1121 - val_mse: 0.0213 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 44/5000
# 1/1 - 2s - loss: 0.1044 - mae: 0.1044 - mse: 0.0210 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0220 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 45/5000
# 1/1 - 3s - loss: 0.1036 - mae: 0.1036 - mse: 0.0211 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0220 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 46/5000
# 1/1 - 2s - loss: 0.1017 - mae: 0.1017 - mse: 0.0208 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0219 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 47/5000
# 1/1 - 3s - loss: 0.1015 - mae: 0.1015 - mse: 0.0205 - val_loss: 0.1147 - val_mae: 0.1147 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 48/5000
# 1/1 - 2s - loss: 0.1003 - mae: 0.1003 - mse: 0.0207 - val_loss: 0.1145 - val_mae: 0.1145 - val_mse: 0.0228 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 49/5000
# 1/1 - 3s - loss: 0.0989 - mae: 0.0989 - mse: 0.0203 - val_loss: 0.1134 - val_mae: 0.1134 - val_mse: 0.0221 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 50/5000
# 1/1 - 3s - loss: 0.0984 - mae: 0.0984 - mse: 0.0198 - val_loss: 0.1139 - val_mae: 0.1139 - val_mse: 0.0228 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 51/5000
# 1/1 - 2s - loss: 0.0989 - mae: 0.0989 - mse: 0.0202 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0218 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 52/5000
# 1/1 - 3s - loss: 0.0981 - mae: 0.0981 - mse: 0.0196 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0221 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 53/5000
# 1/1 - 3s - loss: 0.0948 - mae: 0.0948 - mse: 0.0193 - val_loss: 0.1142 - val_mae: 0.1142 - val_mse: 0.0231 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 54/5000
# 1/1 - 2s - loss: 0.0958 - mae: 0.0958 - mse: 0.0197 - val_loss: 0.1144 - val_mae: 0.1144 - val_mse: 0.0223 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 55/5000
# 1/1 - 2s - loss: 0.1012 - mae: 0.1012 - mse: 0.0198 - val_loss: 0.1149 - val_mae: 0.1149 - val_mse: 0.0234 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 56/5000
# 1/1 - 3s - loss: 0.0952 - mae: 0.0952 - mse: 0.0195 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0218 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 57/5000
# 1/1 - 3s - loss: 0.0922 - mae: 0.0922 - mse: 0.0184 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0221 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 58/5000
# 1/1 - 2s - loss: 0.0910 - mae: 0.0910 - mse: 0.0183 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0222 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 59/5000
# 1/1 - 2s - loss: 0.0898 - mae: 0.0898 - mse: 0.0180 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0230 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 60/5000
# 1/1 - 3s - loss: 0.0895 - mae: 0.0895 - mse: 0.0182 - val_loss: 0.1128 - val_mae: 0.1128 - val_mse: 0.0222 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 61/5000
# 1/1 - 3s - loss: 0.0948 - mae: 0.0948 - mse: 0.0183 - val_loss: 0.1180 - val_mae: 0.1180 - val_mse: 0.0256 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 62/5000
# 1/1 - 2s - loss: 0.1041 - mae: 0.1041 - mse: 0.0209 - val_loss: 0.1135 - val_mae: 0.1135 - val_mse: 0.0222 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 63/5000
# 1/1 - 3s - loss: 0.0984 - mae: 0.0984 - mse: 0.0187 - val_loss: 0.1104 - val_mae: 0.1104 - val_mse: 0.0216 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 64/5000
# 1/1 - 3s - loss: 0.0872 - mae: 0.0872 - mse: 0.0172 - val_loss: 0.1171 - val_mae: 0.1171 - val_mse: 0.0247 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 65/5000
# 1/1 - 3s - loss: 0.0983 - mae: 0.0983 - mse: 0.0193 - val_loss: 0.1204 - val_mae: 0.1204 - val_mse: 0.0245 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 66/5000
# 1/1 - 2s - loss: 0.1090 - mae: 0.1090 - mse: 0.0206 - val_loss: 0.1113 - val_mae: 0.1113 - val_mse: 0.0218 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 67/5000
# 1/1 - 2s - loss: 0.0859 - mae: 0.0859 - mse: 0.0166 - val_loss: 0.1276 - val_mae: 0.1276 - val_mse: 0.0287 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 68/5000
# 1/1 - 3s - loss: 0.1141 - mae: 0.1141 - mse: 0.0225 - val_loss: 0.1103 - val_mae: 0.1103 - val_mse: 0.0213 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 69/5000
# 1/1 - 3s - loss: 0.0921 - mae: 0.0921 - mse: 0.0172 - val_loss: 0.1093 - val_mae: 0.1093 - val_mse: 0.0210 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 70/5000
# 1/1 - 3s - loss: 0.0913 - mae: 0.0913 - mse: 0.0172 - val_loss: 0.1154 - val_mae: 0.1154 - val_mse: 0.0240 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 71/5000
# 1/1 - 2s - loss: 0.0992 - mae: 0.0992 - mse: 0.0189 - val_loss: 0.1097 - val_mae: 0.1097 - val_mse: 0.0215 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 72/5000
# 1/1 - 2s - loss: 0.0843 - mae: 0.0843 - mse: 0.0160 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0226 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 73/5000
# 1/1 - 3s - loss: 0.0880 - mae: 0.0880 - mse: 0.0167 - val_loss: 0.1182 - val_mae: 0.1182 - val_mse: 0.0252 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 74/5000
# 1/1 - 2s - loss: 0.0930 - mae: 0.0930 - mse: 0.0177 - val_loss: 0.1114 - val_mae: 0.1114 - val_mse: 0.0221 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 75/5000
# 1/1 - 3s - loss: 0.0866 - mae: 0.0866 - mse: 0.0162 - val_loss: 0.1111 - val_mae: 0.1111 - val_mse: 0.0223 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 76/5000
# 1/1 - 3s - loss: 0.0904 - mae: 0.0904 - mse: 0.0170 - val_loss: 0.1093 - val_mae: 0.1093 - val_mse: 0.0215 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 77/5000
# 1/1 - 3s - loss: 0.0835 - mae: 0.0835 - mse: 0.0158 - val_loss: 0.1118 - val_mae: 0.1118 - val_mse: 0.0227 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 78/5000
# 1/1 - 2s - loss: 0.0804 - mae: 0.0804 - mse: 0.0154 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0230 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 79/5000
# 1/1 - 3s - loss: 0.0807 - mae: 0.0807 - mse: 0.0153 - val_loss: 0.1113 - val_mae: 0.1113 - val_mse: 0.0222 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 80/5000
# 1/1 - 3s - loss: 0.0793 - mae: 0.0793 - mse: 0.0148 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0230 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 81/5000
# 1/1 - 3s - loss: 0.0847 - mae: 0.0847 - mse: 0.0156 - val_loss: 0.1144 - val_mae: 0.1144 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 82/5000
# 1/1 - 2s - loss: 0.0943 - mae: 0.0943 - mse: 0.0172 - val_loss: 0.1103 - val_mae: 0.1103 - val_mse: 0.0226 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 83/5000
# 1/1 - 2s - loss: 0.0847 - mae: 0.0847 - mse: 0.0157 - val_loss: 0.1094 - val_mae: 0.1094 - val_mse: 0.0220 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 84/5000
# 1/1 - 2s - loss: 0.0753 - mae: 0.0753 - mse: 0.0143 - val_loss: 0.1135 - val_mae: 0.1135 - val_mse: 0.0234 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 85/5000
# 1/1 - 2s - loss: 0.0871 - mae: 0.0871 - mse: 0.0158 - val_loss: 0.1291 - val_mae: 0.1291 - val_mse: 0.0293 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 86/5000
# 1/1 - 3s - loss: 0.1064 - mae: 0.1064 - mse: 0.0205 - val_loss: 0.1118 - val_mae: 0.1118 - val_mse: 0.0225 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 87/5000
# 1/1 - 2s - loss: 0.0824 - mae: 0.0824 - mse: 0.0149 - val_loss: 0.1093 - val_mae: 0.1093 - val_mse: 0.0217 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 88/5000
# 1/1 - 2s - loss: 0.0761 - mae: 0.0761 - mse: 0.0142 - val_loss: 0.1094 - val_mae: 0.1094 - val_mse: 0.0222 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 89/5000
# 1/1 - 3s - loss: 0.0776 - mae: 0.0776 - mse: 0.0144 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0224 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 90/5000
# 1/1 - 2s - loss: 0.0822 - mae: 0.0822 - mse: 0.0147 - val_loss: 0.1230 - val_mae: 0.1230 - val_mse: 0.0269 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 91/5000
# 1/1 - 2s - loss: 0.0965 - mae: 0.0965 - mse: 0.0171 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0228 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 92/5000
# 1/1 - 3s - loss: 0.0838 - mae: 0.0838 - mse: 0.0148 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0226 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 93/5000
# 1/1 - 3s - loss: 0.0771 - mae: 0.0771 - mse: 0.0139 - val_loss: 0.1098 - val_mae: 0.1098 - val_mse: 0.0221 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 94/5000
# 1/1 - 3s - loss: 0.0702 - mae: 0.0702 - mse: 0.0131 - val_loss: 0.1102 - val_mae: 0.1102 - val_mse: 0.0223 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 95/5000
# 1/1 - 2s - loss: 0.0783 - mae: 0.0783 - mse: 0.0140 - val_loss: 0.1212 - val_mae: 0.1212 - val_mse: 0.0268 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 96/5000
# 1/1 - 3s - loss: 0.0957 - mae: 0.0957 - mse: 0.0170 - val_loss: 0.1093 - val_mae: 0.1093 - val_mse: 0.0221 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 97/5000
# 1/1 - 3s - loss: 0.0807 - mae: 0.0807 - mse: 0.0140 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0220 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 98/5000
# 1/1 - 2s - loss: 0.0731 - mae: 0.0731 - mse: 0.0130 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0224 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 99/5000
# 1/1 - 2s - loss: 0.0683 - mae: 0.0683 - mse: 0.0125 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0231 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 100/5000
# 1/1 - 2s - loss: 0.0722 - mae: 0.0722 - mse: 0.0130 - val_loss: 0.1199 - val_mae: 0.1199 - val_mse: 0.0260 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 101/5000
# 1/1 - 2s - loss: 0.0896 - mae: 0.0896 - mse: 0.0153 - val_loss: 0.1158 - val_mae: 0.1158 - val_mse: 0.0234 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 102/5000
# 1/1 - 2s - loss: 0.0892 - mae: 0.0892 - mse: 0.0156 - val_loss: 0.1105 - val_mae: 0.1105 - val_mse: 0.0219 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 103/5000
# 1/1 - 3s - loss: 0.0783 - mae: 0.0783 - mse: 0.0135 - val_loss: 0.1078 - val_mae: 0.1078 - val_mse: 0.0214 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 104/5000
# 1/1 - 2s - loss: 0.0680 - mae: 0.0680 - mse: 0.0122 - val_loss: 0.1093 - val_mae: 0.1093 - val_mse: 0.0223 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 105/5000
# 1/1 - 3s - loss: 0.0677 - mae: 0.0677 - mse: 0.0121 - val_loss: 0.1140 - val_mae: 0.1140 - val_mse: 0.0239 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 106/5000
# 1/1 - 2s - loss: 0.0754 - mae: 0.0754 - mse: 0.0130 - val_loss: 0.1201 - val_mae: 0.1201 - val_mse: 0.0247 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 107/5000
# 1/1 - 3s - loss: 0.0936 - mae: 0.0936 - mse: 0.0161 - val_loss: 0.1149 - val_mae: 0.1149 - val_mse: 0.0234 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 108/5000
# 1/1 - 3s - loss: 0.0862 - mae: 0.0862 - mse: 0.0153 - val_loss: 0.1103 - val_mae: 0.1103 - val_mse: 0.0222 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 109/5000
# 1/1 - 3s - loss: 0.0685 - mae: 0.0685 - mse: 0.0121 - val_loss: 0.1203 - val_mae: 0.1203 - val_mse: 0.0260 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 110/5000
# 1/1 - 2s - loss: 0.0968 - mae: 0.0968 - mse: 0.0167 - val_loss: 0.1372 - val_mae: 0.1372 - val_mse: 0.0326 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 111/5000
# 1/1 - 3s - loss: 0.1086 - mae: 0.1086 - mse: 0.0206 - val_loss: 0.1138 - val_mae: 0.1138 - val_mse: 0.0240 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 112/5000
# 1/1 - 2s - loss: 0.0781 - mae: 0.0781 - mse: 0.0139 - val_loss: 0.1175 - val_mae: 0.1175 - val_mse: 0.0240 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 113/5000
# 1/1 - 3s - loss: 0.0876 - mae: 0.0876 - mse: 0.0149 - val_loss: 0.1196 - val_mae: 0.1196 - val_mse: 0.0253 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 114/5000
# 1/1 - 3s - loss: 0.1014 - mae: 0.1014 - mse: 0.0182 - val_loss: 0.1105 - val_mae: 0.1105 - val_mse: 0.0215 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 115/5000
# 1/1 - 2s - loss: 0.0815 - mae: 0.0815 - mse: 0.0143 - val_loss: 0.1269 - val_mae: 0.1269 - val_mse: 0.0259 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 116/5000
# 1/1 - 2s - loss: 0.1030 - mae: 0.1030 - mse: 0.0187 - val_loss: 0.1095 - val_mae: 0.1095 - val_mse: 0.0218 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 117/5000
# 1/1 - 2s - loss: 0.0794 - mae: 0.0794 - mse: 0.0137 - val_loss: 0.1220 - val_mae: 0.1220 - val_mse: 0.0263 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 118/5000
# 1/1 - 2s - loss: 0.0933 - mae: 0.0933 - mse: 0.0160 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0232 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 119/5000
# 1/1 - 3s - loss: 0.0813 - mae: 0.0813 - mse: 0.0139 - val_loss: 0.1103 - val_mae: 0.1103 - val_mse: 0.0226 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 120/5000
# 1/1 - 2s - loss: 0.0727 - mae: 0.0727 - mse: 0.0125 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0233 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 121/5000
# 1/1 - 2s - loss: 0.0804 - mae: 0.0804 - mse: 0.0141 - val_loss: 0.1161 - val_mae: 0.1161 - val_mse: 0.0231 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 122/5000
# 1/1 - 3s - loss: 0.0818 - mae: 0.0818 - mse: 0.0142 - val_loss: 0.1109 - val_mae: 0.1109 - val_mse: 0.0221 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 123/5000
# 1/1 - 2s - loss: 0.0737 - mae: 0.0737 - mse: 0.0129 - val_loss: 0.1117 - val_mae: 0.1117 - val_mse: 0.0233 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 124/5000
# 1/1 - 2s - loss: 0.0750 - mae: 0.0750 - mse: 0.0128 - val_loss: 0.1105 - val_mae: 0.1105 - val_mse: 0.0231 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 125/5000
# 1/1 - 2s - loss: 0.0811 - mae: 0.0811 - mse: 0.0137 - val_loss: 0.1169 - val_mae: 0.1169 - val_mse: 0.0251 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 126/5000
# 1/1 - 3s - loss: 0.0767 - mae: 0.0767 - mse: 0.0127 - val_loss: 0.1114 - val_mae: 0.1114 - val_mse: 0.0234 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 127/5000
# 1/1 - 3s - loss: 0.0680 - mae: 0.0680 - mse: 0.0114 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0231 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 128/5000
# 1/1 - 2s - loss: 0.0711 - mae: 0.0711 - mse: 0.0119 - val_loss: 0.1143 - val_mae: 0.1143 - val_mse: 0.0243 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 129/5000
# 1/1 - 2s - loss: 0.0823 - mae: 0.0823 - mse: 0.0135 - val_loss: 0.1089 - val_mae: 0.1089 - val_mse: 0.0218 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 130/5000
# 1/1 - 3s - loss: 0.0682 - mae: 0.0682 - mse: 0.0115 - val_loss: 0.1086 - val_mae: 0.1086 - val_mse: 0.0217 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 131/5000
# 1/1 - 2s - loss: 0.0690 - mae: 0.0690 - mse: 0.0115 - val_loss: 0.1197 - val_mae: 0.1197 - val_mse: 0.0253 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 132/5000
# 1/1 - 2s - loss: 0.0835 - mae: 0.0835 - mse: 0.0135 - val_loss: 0.1088 - val_mae: 0.1088 - val_mse: 0.0224 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 133/5000
# 1/1 - 2s - loss: 0.0663 - mae: 0.0663 - mse: 0.0112 - val_loss: 0.1115 - val_mae: 0.1115 - val_mse: 0.0233 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 134/5000
# 1/1 - 3s - loss: 0.0641 - mae: 0.0641 - mse: 0.0111 - val_loss: 0.1112 - val_mae: 0.1112 - val_mse: 0.0228 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 135/5000
# 1/1 - 2s - loss: 0.0604 - mae: 0.0604 - mse: 0.0105 - val_loss: 0.1096 - val_mae: 0.1096 - val_mse: 0.0219 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 136/5000
# 1/1 - 2s - loss: 0.0602 - mae: 0.0602 - mse: 0.0104 - val_loss: 0.1116 - val_mae: 0.1116 - val_mse: 0.0227 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 137/5000
# 1/1 - 2s - loss: 0.0662 - mae: 0.0662 - mse: 0.0107 - val_loss: 0.1120 - val_mae: 0.1120 - val_mse: 0.0233 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 138/5000
# 1/1 - 3s - loss: 0.0766 - mae: 0.0766 - mse: 0.0122 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0240 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 139/5000
# 1/1 - 3s - loss: 0.0717 - mae: 0.0717 - mse: 0.0114 - val_loss: 0.1085 - val_mae: 0.1085 - val_mse: 0.0224 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 140/5000
# 1/1 - 2s - loss: 0.0587 - mae: 0.0587 - mse: 0.0099 - val_loss: 0.1103 - val_mae: 0.1103 - val_mse: 0.0223 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 141/5000
# 1/1 - 2s - loss: 0.0610 - mae: 0.0610 - mse: 0.0102 - val_loss: 0.1175 - val_mae: 0.1175 - val_mse: 0.0247 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 142/5000
# 1/1 - 3s - loss: 0.0768 - mae: 0.0768 - mse: 0.0119 - val_loss: 0.1166 - val_mae: 0.1166 - val_mse: 0.0237 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 143/5000
# 1/1 - 2s - loss: 0.0761 - mae: 0.0761 - mse: 0.0123 - val_loss: 0.1115 - val_mae: 0.1115 - val_mse: 0.0233 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 144/5000
# 1/1 - 2s - loss: 0.0627 - mae: 0.0627 - mse: 0.0103 - val_loss: 0.1099 - val_mae: 0.1099 - val_mse: 0.0232 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 145/5000
# 1/1 - 2s - loss: 0.0572 - mae: 0.0572 - mse: 0.0095 - val_loss: 0.1084 - val_mae: 0.1084 - val_mse: 0.0224 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 146/5000
# 1/1 - 3s - loss: 0.0577 - mae: 0.0577 - mse: 0.0094 - val_loss: 0.1188 - val_mae: 0.1188 - val_mse: 0.0251 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 147/5000
# 1/1 - 3s - loss: 0.0786 - mae: 0.0786 - mse: 0.0121 - val_loss: 0.1145 - val_mae: 0.1145 - val_mse: 0.0235 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 148/5000
# 1/1 - 2s - loss: 0.0733 - mae: 0.0733 - mse: 0.0114 - val_loss: 0.1085 - val_mae: 0.1085 - val_mse: 0.0221 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 149/5000
# 1/1 - 2s - loss: 0.0583 - mae: 0.0583 - mse: 0.0094 - val_loss: 0.1121 - val_mae: 0.1121 - val_mse: 0.0232 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 150/5000
# 1/1 - 3s - loss: 0.0603 - mae: 0.0603 - mse: 0.0094 - val_loss: 0.1230 - val_mae: 0.1230 - val_mse: 0.0260 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 151/5000
# 1/1 - 3s - loss: 0.0878 - mae: 0.0878 - mse: 0.0132 - val_loss: 0.1144 - val_mae: 0.1144 - val_mse: 0.0240 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 152/5000
# 1/1 - 3s - loss: 0.0618 - mae: 0.0618 - mse: 0.0096 - val_loss: 0.1112 - val_mae: 0.1112 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 153/5000
# 1/1 - 3s - loss: 0.0553 - mae: 0.0553 - mse: 0.0088 - val_loss: 0.1199 - val_mae: 0.1199 - val_mse: 0.0249 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 154/5000
# 1/1 - 3s - loss: 0.0815 - mae: 0.0815 - mse: 0.0120 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0236 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 155/5000
# 1/1 - 3s - loss: 0.0689 - mae: 0.0689 - mse: 0.0105 - val_loss: 0.1076 - val_mae: 0.1076 - val_mse: 0.0216 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 156/5000
# 1/1 - 3s - loss: 0.0545 - mae: 0.0545 - mse: 0.0087 - val_loss: 0.1110 - val_mae: 0.1110 - val_mse: 0.0228 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 157/5000
# 1/1 - 3s - loss: 0.0632 - mae: 0.0632 - mse: 0.0096 - val_loss: 0.1239 - val_mae: 0.1239 - val_mse: 0.0275 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 158/5000
# 1/1 - 3s - loss: 0.0826 - mae: 0.0826 - mse: 0.0127 - val_loss: 0.1122 - val_mae: 0.1122 - val_mse: 0.0237 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 159/5000
# 1/1 - 3s - loss: 0.0576 - mae: 0.0576 - mse: 0.0089 - val_loss: 0.1113 - val_mae: 0.1113 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 160/5000
# 1/1 - 2s - loss: 0.0576 - mae: 0.0576 - mse: 0.0090 - val_loss: 0.1089 - val_mae: 0.1089 - val_mse: 0.0221 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 161/5000
# 1/1 - 2s - loss: 0.0545 - mae: 0.0545 - mse: 0.0087 - val_loss: 0.1086 - val_mae: 0.1086 - val_mse: 0.0220 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 162/5000
# 1/1 - 3s - loss: 0.0516 - mae: 0.0516 - mse: 0.0082 - val_loss: 0.1118 - val_mae: 0.1118 - val_mse: 0.0231 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 163/5000
# 1/1 - 2s - loss: 0.0558 - mae: 0.0558 - mse: 0.0086 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0235 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 164/5000
# 1/1 - 3s - loss: 0.0567 - mae: 0.0567 - mse: 0.0086 - val_loss: 0.1177 - val_mae: 0.1177 - val_mse: 0.0252 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 165/5000
# 1/1 - 2s - loss: 0.0669 - mae: 0.0669 - mse: 0.0094 - val_loss: 0.1207 - val_mae: 0.1207 - val_mse: 0.0252 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 166/5000
# 1/1 - 3s - loss: 0.0837 - mae: 0.0837 - mse: 0.0120 - val_loss: 0.1106 - val_mae: 0.1106 - val_mse: 0.0227 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 167/5000
# 1/1 - 2s - loss: 0.0560 - mae: 0.0560 - mse: 0.0083 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0226 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 168/5000
# 1/1 - 3s - loss: 0.0534 - mae: 0.0534 - mse: 0.0079 - val_loss: 0.1255 - val_mae: 0.1255 - val_mse: 0.0263 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 169/5000
# 1/1 - 2s - loss: 0.0881 - mae: 0.0881 - mse: 0.0123 - val_loss: 0.1148 - val_mae: 0.1148 - val_mse: 0.0239 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 170/5000
# 1/1 - 3s - loss: 0.0650 - mae: 0.0650 - mse: 0.0097 - val_loss: 0.1118 - val_mae: 0.1118 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 171/5000
# 1/1 - 3s - loss: 0.0563 - mae: 0.0563 - mse: 0.0083 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0232 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 172/5000
# 1/1 - 2s - loss: 0.0765 - mae: 0.0765 - mse: 0.0106 - val_loss: 0.1189 - val_mae: 0.1189 - val_mse: 0.0248 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 173/5000
# 1/1 - 3s - loss: 0.0745 - mae: 0.0745 - mse: 0.0110 - val_loss: 0.1099 - val_mae: 0.1099 - val_mse: 0.0224 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 174/5000
# 1/1 - 3s - loss: 0.0599 - mae: 0.0599 - mse: 0.0087 - val_loss: 0.1144 - val_mae: 0.1144 - val_mse: 0.0238 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 175/5000
# 1/1 - 2s - loss: 0.0680 - mae: 0.0680 - mse: 0.0096 - val_loss: 0.1155 - val_mae: 0.1155 - val_mse: 0.0253 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 176/5000
# 1/1 - 2s - loss: 0.0713 - mae: 0.0713 - mse: 0.0101 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0234 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 177/5000
# 1/1 - 2s - loss: 0.0606 - mae: 0.0606 - mse: 0.0090 - val_loss: 0.1119 - val_mae: 0.1119 - val_mse: 0.0230 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 178/5000
# 1/1 - 3s - loss: 0.0637 - mae: 0.0637 - mse: 0.0093 - val_loss: 0.1194 - val_mae: 0.1194 - val_mse: 0.0246 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 179/5000
# 1/1 - 2s - loss: 0.0670 - mae: 0.0670 - mse: 0.0092 - val_loss: 0.1082 - val_mae: 0.1082 - val_mse: 0.0220 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 180/5000
# 1/1 - 2s - loss: 0.0627 - mae: 0.0627 - mse: 0.0087 - val_loss: 0.1096 - val_mae: 0.1096 - val_mse: 0.0225 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 181/5000
# 1/1 - 3s - loss: 0.0549 - mae: 0.0549 - mse: 0.0078 - val_loss: 0.1141 - val_mae: 0.1141 - val_mse: 0.0237 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 182/5000
# 1/1 - 2s - loss: 0.0601 - mae: 0.0601 - mse: 0.0086 - val_loss: 0.1138 - val_mae: 0.1138 - val_mse: 0.0230 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 183/5000
# 1/1 - 3s - loss: 0.0591 - mae: 0.0591 - mse: 0.0084 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0236 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 184/5000
# 1/1 - 2s - loss: 0.0615 - mae: 0.0615 - mse: 0.0086 - val_loss: 0.1105 - val_mae: 0.1105 - val_mse: 0.0237 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 185/5000
# 1/1 - 3s - loss: 0.0558 - mae: 0.0558 - mse: 0.0079 - val_loss: 0.1105 - val_mae: 0.1105 - val_mse: 0.0239 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 186/5000
# 1/1 - 2s - loss: 0.0521 - mae: 0.0521 - mse: 0.0075 - val_loss: 0.1113 - val_mae: 0.1113 - val_mse: 0.0229 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 187/5000
# 1/1 - 2s - loss: 0.0481 - mae: 0.0481 - mse: 0.0069 - val_loss: 0.1097 - val_mae: 0.1097 - val_mse: 0.0216 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 188/5000
# 1/1 - 3s - loss: 0.0495 - mae: 0.0495 - mse: 0.0070 - val_loss: 0.1208 - val_mae: 0.1208 - val_mse: 0.0251 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 189/5000
# 1/1 - 2s - loss: 0.0679 - mae: 0.0679 - mse: 0.0091 - val_loss: 0.1109 - val_mae: 0.1109 - val_mse: 0.0223 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 190/5000
# 1/1 - 3s - loss: 0.0644 - mae: 0.0644 - mse: 0.0086 - val_loss: 0.1104 - val_mae: 0.1104 - val_mse: 0.0228 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 191/5000
# 1/1 - 2s - loss: 0.0477 - mae: 0.0477 - mse: 0.0066 - val_loss: 0.1116 - val_mae: 0.1116 - val_mse: 0.0226 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 192/5000
# 1/1 - 2s - loss: 0.0474 - mae: 0.0474 - mse: 0.0068 - val_loss: 0.1140 - val_mae: 0.1140 - val_mse: 0.0234 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 193/5000
# 1/1 - 2s - loss: 0.0602 - mae: 0.0602 - mse: 0.0080 - val_loss: 0.1189 - val_mae: 0.1189 - val_mse: 0.0253 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 194/5000
# 1/1 - 2s - loss: 0.0707 - mae: 0.0707 - mse: 0.0095 - val_loss: 0.1115 - val_mae: 0.1115 - val_mse: 0.0235 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 195/5000
# 1/1 - 2s - loss: 0.0505 - mae: 0.0505 - mse: 0.0071 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0238 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 196/5000
# 1/1 - 3s - loss: 0.0476 - mae: 0.0476 - mse: 0.0067 - val_loss: 0.1208 - val_mae: 0.1208 - val_mse: 0.0263 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 197/5000
# 1/1 - 2s - loss: 0.0715 - mae: 0.0715 - mse: 0.0092 - val_loss: 0.1148 - val_mae: 0.1148 - val_mse: 0.0235 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 198/5000
# 1/1 - 3s - loss: 0.0576 - mae: 0.0576 - mse: 0.0078 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0230 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 199/5000
# 1/1 - 2s - loss: 0.0438 - mae: 0.0438 - mse: 0.0061 - val_loss: 0.1117 - val_mae: 0.1117 - val_mse: 0.0232 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 200/5000
# 1/1 - 3s - loss: 0.0438 - mae: 0.0438 - mse: 0.0059 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0237 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 201/5000
# 1/1 - 2s - loss: 0.0448 - mae: 0.0448 - mse: 0.0062 - val_loss: 0.1114 - val_mae: 0.1114 - val_mse: 0.0235 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 202/5000
# 1/1 - 3s - loss: 0.0416 - mae: 0.0416 - mse: 0.0057 - val_loss: 0.1163 - val_mae: 0.1163 - val_mse: 0.0250 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 203/5000
# 1/1 - 2s - loss: 0.0576 - mae: 0.0576 - mse: 0.0071 - val_loss: 0.1219 - val_mae: 0.1219 - val_mse: 0.0259 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 204/5000
# 1/1 - 3s - loss: 0.0716 - mae: 0.0716 - mse: 0.0089 - val_loss: 0.1101 - val_mae: 0.1101 - val_mse: 0.0231 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 205/5000
# 1/1 - 3s - loss: 0.0491 - mae: 0.0491 - mse: 0.0063 - val_loss: 0.1093 - val_mae: 0.1093 - val_mse: 0.0229 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 206/5000
# 1/1 - 3s - loss: 0.0457 - mae: 0.0457 - mse: 0.0059 - val_loss: 0.1188 - val_mae: 0.1188 - val_mse: 0.0247 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 207/5000
# 1/1 - 3s - loss: 0.0742 - mae: 0.0742 - mse: 0.0090 - val_loss: 0.1141 - val_mae: 0.1141 - val_mse: 0.0239 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 208/5000
# 1/1 - 2s - loss: 0.0521 - mae: 0.0521 - mse: 0.0066 - val_loss: 0.1081 - val_mae: 0.1081 - val_mse: 0.0222 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 209/5000
# 1/1 - 2s - loss: 0.0426 - mae: 0.0426 - mse: 0.0056 - val_loss: 0.1090 - val_mae: 0.1090 - val_mse: 0.0225 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 210/5000
# 1/1 - 2s - loss: 0.0409 - mae: 0.0409 - mse: 0.0053 - val_loss: 0.1195 - val_mae: 0.1195 - val_mse: 0.0255 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 211/5000
# 1/1 - 3s - loss: 0.0565 - mae: 0.0565 - mse: 0.0068 - val_loss: 0.1175 - val_mae: 0.1175 - val_mse: 0.0246 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 212/5000
# 1/1 - 2s - loss: 0.0691 - mae: 0.0691 - mse: 0.0081 - val_loss: 0.1150 - val_mae: 0.1150 - val_mse: 0.0239 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 213/5000
# 1/1 - 2s - loss: 0.0455 - mae: 0.0455 - mse: 0.0057 - val_loss: 0.1098 - val_mae: 0.1098 - val_mse: 0.0226 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 214/5000
# 1/1 - 2s - loss: 0.0385 - mae: 0.0385 - mse: 0.0050 - val_loss: 0.1102 - val_mae: 0.1102 - val_mse: 0.0227 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 215/5000
# 1/1 - 3s - loss: 0.0459 - mae: 0.0459 - mse: 0.0056 - val_loss: 0.1288 - val_mae: 0.1288 - val_mse: 0.0284 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 216/5000
# 1/1 - 2s - loss: 0.0825 - mae: 0.0825 - mse: 0.0102 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0231 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 217/5000
# 1/1 - 2s - loss: 0.0433 - mae: 0.0433 - mse: 0.0056 - val_loss: 0.1231 - val_mae: 0.1231 - val_mse: 0.0260 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 218/5000
# 1/1 - 2s - loss: 0.0738 - mae: 0.0738 - mse: 0.0086 - val_loss: 0.1155 - val_mae: 0.1155 - val_mse: 0.0245 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 219/5000
# 1/1 - 3s - loss: 0.0465 - mae: 0.0465 - mse: 0.0056 - val_loss: 0.1107 - val_mae: 0.1107 - val_mse: 0.0232 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 220/5000
# 1/1 - 2s - loss: 0.0369 - mae: 0.0369 - mse: 0.0047 - val_loss: 0.1109 - val_mae: 0.1109 - val_mse: 0.0224 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 221/5000
# 1/1 - 3s - loss: 0.0428 - mae: 0.0428 - mse: 0.0052 - val_loss: 0.1259 - val_mae: 0.1259 - val_mse: 0.0270 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 222/5000
# 1/1 - 2s - loss: 0.0712 - mae: 0.0712 - mse: 0.0085 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0222 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 223/5000
# 1/1 - 3s - loss: 0.0444 - mae: 0.0444 - mse: 0.0055 - val_loss: 0.1140 - val_mae: 0.1140 - val_mse: 0.0233 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 224/5000
# 1/1 - 2s - loss: 0.0557 - mae: 0.0557 - mse: 0.0061 - val_loss: 0.1350 - val_mae: 0.1350 - val_mse: 0.0303 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 225/5000
# 1/1 - 2s - loss: 0.0788 - mae: 0.0788 - mse: 0.0094 - val_loss: 0.1179 - val_mae: 0.1179 - val_mse: 0.0256 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 226/5000
# 1/1 - 2s - loss: 0.0502 - mae: 0.0502 - mse: 0.0058 - val_loss: 0.1253 - val_mae: 0.1253 - val_mse: 0.0276 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 227/5000
# 1/1 - 3s - loss: 0.0882 - mae: 0.0882 - mse: 0.0109 - val_loss: 0.1099 - val_mae: 0.1099 - val_mse: 0.0226 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 228/5000
# 1/1 - 3s - loss: 0.0438 - mae: 0.0438 - mse: 0.0053 - val_loss: 0.1355 - val_mae: 0.1355 - val_mse: 0.0311 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 229/5000
# 1/1 - 2s - loss: 0.0929 - mae: 0.0929 - mse: 0.0128 - val_loss: 0.1120 - val_mae: 0.1120 - val_mse: 0.0237 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 230/5000
# 1/1 - 2s - loss: 0.0532 - mae: 0.0532 - mse: 0.0070 - val_loss: 0.1381 - val_mae: 0.1381 - val_mse: 0.0298 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 231/5000
# 1/1 - 2s - loss: 0.0933 - mae: 0.0933 - mse: 0.0126 - val_loss: 0.1139 - val_mae: 0.1139 - val_mse: 0.0232 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 232/5000
# 1/1 - 2s - loss: 0.0587 - mae: 0.0587 - mse: 0.0074 - val_loss: 0.1393 - val_mae: 0.1393 - val_mse: 0.0311 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 233/5000
# 1/1 - 2s - loss: 0.0976 - mae: 0.0976 - mse: 0.0141 - val_loss: 0.1306 - val_mae: 0.1306 - val_mse: 0.0281 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 234/5000
# 1/1 - 2s - loss: 0.0800 - mae: 0.0800 - mse: 0.0111 - val_loss: 0.1162 - val_mae: 0.1162 - val_mse: 0.0246 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 235/5000
# 1/1 - 3s - loss: 0.0812 - mae: 0.0812 - mse: 0.0111 - val_loss: 0.1161 - val_mae: 0.1161 - val_mse: 0.0238 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 236/5000
# 1/1 - 3s - loss: 0.0746 - mae: 0.0746 - mse: 0.0093 - val_loss: 0.1222 - val_mae: 0.1222 - val_mse: 0.0266 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 237/5000
# 1/1 - 3s - loss: 0.0699 - mae: 0.0699 - mse: 0.0091 - val_loss: 0.1183 - val_mae: 0.1183 - val_mse: 0.0257 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 238/5000
# 1/1 - 3s - loss: 0.0675 - mae: 0.0675 - mse: 0.0088 - val_loss: 0.1151 - val_mae: 0.1151 - val_mse: 0.0233 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 239/5000
# 1/1 - 3s - loss: 0.0683 - mae: 0.0683 - mse: 0.0087 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0228 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 240/5000
# 1/1 - 2s - loss: 0.0614 - mae: 0.0614 - mse: 0.0082 - val_loss: 0.1230 - val_mae: 0.1230 - val_mse: 0.0262 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 241/5000
# 1/1 - 2s - loss: 0.0683 - mae: 0.0683 - mse: 0.0090 - val_loss: 0.1172 - val_mae: 0.1172 - val_mse: 0.0250 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 242/5000
# 1/1 - 3s - loss: 0.0495 - mae: 0.0495 - mse: 0.0060 - val_loss: 0.1204 - val_mae: 0.1204 - val_mse: 0.0265 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 243/5000
# 1/1 - 3s - loss: 0.0636 - mae: 0.0636 - mse: 0.0080 - val_loss: 0.1183 - val_mae: 0.1183 - val_mse: 0.0257 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 244/5000
# 1/1 - 2s - loss: 0.0573 - mae: 0.0573 - mse: 0.0073 - val_loss: 0.1156 - val_mae: 0.1156 - val_mse: 0.0243 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 245/5000
# 1/1 - 3s - loss: 0.0522 - mae: 0.0522 - mse: 0.0063 - val_loss: 0.1095 - val_mae: 0.1095 - val_mse: 0.0219 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 246/5000
# 1/1 - 2s - loss: 0.0458 - mae: 0.0458 - mse: 0.0058 - val_loss: 0.1098 - val_mae: 0.1098 - val_mse: 0.0217 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 247/5000
# 1/1 - 3s - loss: 0.0483 - mae: 0.0483 - mse: 0.0065 - val_loss: 0.1108 - val_mae: 0.1108 - val_mse: 0.0223 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 248/5000
# 1/1 - 2s - loss: 0.0461 - mae: 0.0461 - mse: 0.0061 - val_loss: 0.1110 - val_mae: 0.1110 - val_mse: 0.0230 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 249/5000
# 1/1 - 2s - loss: 0.0423 - mae: 0.0423 - mse: 0.0054 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0238 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 250/5000
# 1/1 - 3s - loss: 0.0384 - mae: 0.0384 - mse: 0.0047 - val_loss: 0.1117 - val_mae: 0.1117 - val_mse: 0.0235 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 251/5000
# 1/1 - 3s - loss: 0.0403 - mae: 0.0403 - mse: 0.0046 - val_loss: 0.1155 - val_mae: 0.1155 - val_mse: 0.0244 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 252/5000
# 1/1 - 3s - loss: 0.0425 - mae: 0.0425 - mse: 0.0049 - val_loss: 0.1108 - val_mae: 0.1108 - val_mse: 0.0230 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 253/5000
# 1/1 - 2s - loss: 0.0392 - mae: 0.0392 - mse: 0.0045 - val_loss: 0.1116 - val_mae: 0.1116 - val_mse: 0.0230 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 254/5000
# 1/1 - 3s - loss: 0.0353 - mae: 0.0353 - mse: 0.0044 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0228 - lr: 0.0010 - 3s/epoch - 3s/step
# Epoch 255/5000
#
# Epoch 00255: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# 1/1 - 2s - loss: 0.0406 - mae: 0.0406 - mse: 0.0048 - val_loss: 0.1169 - val_mae: 0.1169 - val_mse: 0.0242 - lr: 0.0010 - 2s/epoch - 2s/step
# Epoch 256/5000
# 1/1 - 3s - loss: 0.0405 - mae: 0.0405 - mse: 0.0047 - val_loss: 0.1156 - val_mae: 0.1156 - val_mse: 0.0238 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 257/5000
# 1/1 - 2s - loss: 0.0373 - mae: 0.0373 - mse: 0.0044 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 258/5000
# 1/1 - 2s - loss: 0.0323 - mae: 0.0323 - mse: 0.0041 - val_loss: 0.1117 - val_mae: 0.1117 - val_mse: 0.0228 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 259/5000
# 1/1 - 3s - loss: 0.0321 - mae: 0.0321 - mse: 0.0040 - val_loss: 0.1114 - val_mae: 0.1114 - val_mse: 0.0228 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 260/5000
# 1/1 - 2s - loss: 0.0342 - mae: 0.0342 - mse: 0.0040 - val_loss: 0.1113 - val_mae: 0.1113 - val_mse: 0.0228 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 261/5000
# 1/1 - 2s - loss: 0.0326 - mae: 0.0326 - mse: 0.0039 - val_loss: 0.1114 - val_mae: 0.1114 - val_mse: 0.0229 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 262/5000
# 1/1 - 3s - loss: 0.0285 - mae: 0.0285 - mse: 0.0037 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0232 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 263/5000
# 1/1 - 3s - loss: 0.0287 - mae: 0.0287 - mse: 0.0037 - val_loss: 0.1136 - val_mae: 0.1136 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 264/5000
# 1/1 - 2s - loss: 0.0307 - mae: 0.0307 - mse: 0.0038 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 265/5000
# 1/1 - 3s - loss: 0.0289 - mae: 0.0289 - mse: 0.0037 - val_loss: 0.1122 - val_mae: 0.1122 - val_mse: 0.0229 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 266/5000
# 1/1 - 2s - loss: 0.0270 - mae: 0.0270 - mse: 0.0036 - val_loss: 0.1120 - val_mae: 0.1120 - val_mse: 0.0228 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 267/5000
# 1/1 - 3s - loss: 0.0286 - mae: 0.0286 - mse: 0.0036 - val_loss: 0.1122 - val_mae: 0.1122 - val_mse: 0.0229 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 268/5000
# 1/1 - 3s - loss: 0.0284 - mae: 0.0284 - mse: 0.0036 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0231 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 269/5000
# 1/1 - 2s - loss: 0.0258 - mae: 0.0258 - mse: 0.0035 - val_loss: 0.1135 - val_mae: 0.1135 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 270/5000
# 1/1 - 2s - loss: 0.0266 - mae: 0.0266 - mse: 0.0036 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 271/5000
# 1/1 - 2s - loss: 0.0273 - mae: 0.0273 - mse: 0.0036 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 272/5000
# 1/1 - 2s - loss: 0.0253 - mae: 0.0253 - mse: 0.0035 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 273/5000
# 1/1 - 2s - loss: 0.0252 - mae: 0.0252 - mse: 0.0035 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0231 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 274/5000
# 1/1 - 3s - loss: 0.0258 - mae: 0.0258 - mse: 0.0035 - val_loss: 0.1126 - val_mae: 0.1126 - val_mse: 0.0232 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 275/5000
# 1/1 - 3s - loss: 0.0238 - mae: 0.0238 - mse: 0.0034 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 276/5000
# 1/1 - 2s - loss: 0.0245 - mae: 0.0245 - mse: 0.0034 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 277/5000
# 1/1 - 3s - loss: 0.0243 - mae: 0.0243 - mse: 0.0034 - val_loss: 0.1124 - val_mae: 0.1124 - val_mse: 0.0231 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 278/5000
# 1/1 - 2s - loss: 0.0232 - mae: 0.0232 - mse: 0.0034 - val_loss: 0.1122 - val_mae: 0.1122 - val_mse: 0.0231 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 279/5000
# 1/1 - 3s - loss: 0.0241 - mae: 0.0241 - mse: 0.0034 - val_loss: 0.1125 - val_mae: 0.1125 - val_mse: 0.0232 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 280/5000
# 1/1 - 2s - loss: 0.0229 - mae: 0.0229 - mse: 0.0034 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 281/5000
# 1/1 - 2s - loss: 0.0234 - mae: 0.0234 - mse: 0.0034 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 282/5000
# 1/1 - 2s - loss: 0.0227 - mae: 0.0227 - mse: 0.0034 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 283/5000
# 1/1 - 3s - loss: 0.0226 - mae: 0.0226 - mse: 0.0034 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0232 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 284/5000
# 1/1 - 2s - loss: 0.0221 - mae: 0.0221 - mse: 0.0033 - val_loss: 0.1135 - val_mae: 0.1135 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 285/5000
# 1/1 - 3s - loss: 0.0225 - mae: 0.0225 - mse: 0.0033 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 286/5000
# 1/1 - 2s - loss: 0.0218 - mae: 0.0218 - mse: 0.0033 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 287/5000
# 1/1 - 3s - loss: 0.0222 - mae: 0.0222 - mse: 0.0033 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 288/5000
# 1/1 - 2s - loss: 0.0214 - mae: 0.0214 - mse: 0.0033 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 289/5000
# 1/1 - 3s - loss: 0.0220 - mae: 0.0220 - mse: 0.0033 - val_loss: 0.1129 - val_mae: 0.1129 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 290/5000
# 1/1 - 2s - loss: 0.0210 - mae: 0.0210 - mse: 0.0033 - val_loss: 0.1127 - val_mae: 0.1127 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 291/5000
# 1/1 - 3s - loss: 0.0215 - mae: 0.0215 - mse: 0.0033 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 292/5000
# 1/1 - 3s - loss: 0.0206 - mae: 0.0206 - mse: 0.0032 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 293/5000
# 1/1 - 3s - loss: 0.0203 - mae: 0.0203 - mse: 0.0032 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 294/5000
# 1/1 - 3s - loss: 0.0205 - mae: 0.0205 - mse: 0.0032 - val_loss: 0.1134 - val_mae: 0.1134 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 295/5000
# 1/1 - 2s - loss: 0.0203 - mae: 0.0203 - mse: 0.0032 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 296/5000
# 1/1 - 3s - loss: 0.0200 - mae: 0.0200 - mse: 0.0032 - val_loss: 0.1135 - val_mae: 0.1135 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 297/5000
# 1/1 - 2s - loss: 0.0200 - mae: 0.0200 - mse: 0.0032 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 298/5000
# 1/1 - 2s - loss: 0.0202 - mae: 0.0202 - mse: 0.0032 - val_loss: 0.1135 - val_mae: 0.1135 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 299/5000
# 1/1 - 3s - loss: 0.0200 - mae: 0.0200 - mse: 0.0032 - val_loss: 0.1131 - val_mae: 0.1131 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 300/5000
# 1/1 - 3s - loss: 0.0202 - mae: 0.0202 - mse: 0.0032 - val_loss: 0.1136 - val_mae: 0.1136 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 301/5000
# 1/1 - 3s - loss: 0.0207 - mae: 0.0207 - mse: 0.0032 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 302/5000
# 1/1 - 3s - loss: 0.0196 - mae: 0.0196 - mse: 0.0031 - val_loss: 0.1132 - val_mae: 0.1132 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 303/5000
# 1/1 - 3s - loss: 0.0202 - mae: 0.0202 - mse: 0.0031 - val_loss: 0.1141 - val_mae: 0.1141 - val_mse: 0.0235 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 304/5000
# 1/1 - 2s - loss: 0.0219 - mae: 0.0219 - mse: 0.0032 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 305/5000
# 1/1 - 2s - loss: 0.0203 - mae: 0.0203 - mse: 0.0031 - val_loss: 0.1130 - val_mae: 0.1130 - val_mse: 0.0232 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 306/5000
# 1/1 - 2s - loss: 0.0223 - mae: 0.0223 - mse: 0.0031 - val_loss: 0.1133 - val_mae: 0.1133 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 307/5000
# 1/1 - 3s - loss: 0.0200 - mae: 0.0200 - mse: 0.0031 - val_loss: 0.1145 - val_mae: 0.1145 - val_mse: 0.0237 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 308/5000
# 1/1 - 2s - loss: 0.0232 - mae: 0.0232 - mse: 0.0032 - val_loss: 0.1143 - val_mae: 0.1143 - val_mse: 0.0236 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 309/5000
# 1/1 - 3s - loss: 0.0211 - mae: 0.0211 - mse: 0.0031 - val_loss: 0.1134 - val_mae: 0.1134 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 310/5000
# 1/1 - 3s - loss: 0.0236 - mae: 0.0236 - mse: 0.0031 - val_loss: 0.1136 - val_mae: 0.1136 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 311/5000
# 1/1 - 3s - loss: 0.0229 - mae: 0.0229 - mse: 0.0031 - val_loss: 0.1148 - val_mae: 0.1148 - val_mse: 0.0237 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 312/5000
# 1/1 - 3s - loss: 0.0215 - mae: 0.0215 - mse: 0.0031 - val_loss: 0.1150 - val_mae: 0.1150 - val_mse: 0.0238 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 313/5000
# 1/1 - 3s - loss: 0.0225 - mae: 0.0225 - mse: 0.0031 - val_loss: 0.1139 - val_mae: 0.1139 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 314/5000
# 1/1 - 3s - loss: 0.0200 - mae: 0.0200 - mse: 0.0030 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 315/5000
# 1/1 - 3s - loss: 0.0205 - mae: 0.0205 - mse: 0.0030 - val_loss: 0.1147 - val_mae: 0.1147 - val_mse: 0.0235 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 316/5000
# 1/1 - 3s - loss: 0.0213 - mae: 0.0213 - mse: 0.0030 - val_loss: 0.1145 - val_mae: 0.1145 - val_mse: 0.0235 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 317/5000
# 1/1 - 2s - loss: 0.0205 - mae: 0.0205 - mse: 0.0030 - val_loss: 0.1134 - val_mae: 0.1134 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 318/5000
# 1/1 - 2s - loss: 0.0215 - mae: 0.0215 - mse: 0.0030 - val_loss: 0.1136 - val_mae: 0.1136 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 319/5000
# 1/1 - 2s - loss: 0.0210 - mae: 0.0210 - mse: 0.0030 - val_loss: 0.1149 - val_mae: 0.1149 - val_mse: 0.0237 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 320/5000
# 1/1 - 3s - loss: 0.0209 - mae: 0.0209 - mse: 0.0030 - val_loss: 0.1148 - val_mae: 0.1148 - val_mse: 0.0236 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 321/5000
# 1/1 - 3s - loss: 0.0196 - mae: 0.0196 - mse: 0.0030 - val_loss: 0.1139 - val_mae: 0.1139 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 322/5000
# 1/1 - 2s - loss: 0.0214 - mae: 0.0214 - mse: 0.0030 - val_loss: 0.1140 - val_mae: 0.1140 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 323/5000
# 1/1 - 3s - loss: 0.0196 - mae: 0.0196 - mse: 0.0030 - val_loss: 0.1152 - val_mae: 0.1152 - val_mse: 0.0237 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 324/5000
# 1/1 - 2s - loss: 0.0220 - mae: 0.0220 - mse: 0.0030 - val_loss: 0.1147 - val_mae: 0.1147 - val_mse: 0.0236 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 325/5000
# 1/1 - 2s - loss: 0.0201 - mae: 0.0201 - mse: 0.0029 - val_loss: 0.1137 - val_mae: 0.1137 - val_mse: 0.0233 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 326/5000
# 1/1 - 3s - loss: 0.0228 - mae: 0.0228 - mse: 0.0030 - val_loss: 0.1138 - val_mae: 0.1138 - val_mse: 0.0233 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 327/5000
# 1/1 - 3s - loss: 0.0220 - mae: 0.0220 - mse: 0.0030 - val_loss: 0.1152 - val_mae: 0.1152 - val_mse: 0.0237 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 328/5000
# 1/1 - 2s - loss: 0.0209 - mae: 0.0209 - mse: 0.0029 - val_loss: 0.1155 - val_mae: 0.1155 - val_mse: 0.0238 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 329/5000
# 1/1 - 2s - loss: 0.0215 - mae: 0.0215 - mse: 0.0029 - val_loss: 0.1143 - val_mae: 0.1143 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 330/5000
# 1/1 - 2s - loss: 0.0198 - mae: 0.0198 - mse: 0.0029 - val_loss: 0.1143 - val_mae: 0.1143 - val_mse: 0.0234 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 331/5000
# 1/1 - 3s - loss: 0.0200 - mae: 0.0200 - mse: 0.0029 - val_loss: 0.1157 - val_mae: 0.1157 - val_mse: 0.0238 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 332/5000
# 1/1 - 2s - loss: 0.0205 - mae: 0.0205 - mse: 0.0029 - val_loss: 0.1154 - val_mae: 0.1154 - val_mse: 0.0238 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 333/5000
# 1/1 - 2s - loss: 0.0191 - mae: 0.0191 - mse: 0.0029 - val_loss: 0.1142 - val_mae: 0.1142 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 334/5000
# 1/1 - 2s - loss: 0.0222 - mae: 0.0222 - mse: 0.0029 - val_loss: 0.1143 - val_mae: 0.1143 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 335/5000
# 1/1 - 3s - loss: 0.0208 - mae: 0.0208 - mse: 0.0029 - val_loss: 0.1158 - val_mae: 0.1158 - val_mse: 0.0239 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 336/5000
# 1/1 - 2s - loss: 0.0214 - mae: 0.0214 - mse: 0.0029 - val_loss: 0.1158 - val_mae: 0.1158 - val_mse: 0.0239 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 337/5000
# 1/1 - 3s - loss: 0.0217 - mae: 0.0217 - mse: 0.0029 - val_loss: 0.1142 - val_mae: 0.1142 - val_mse: 0.0235 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 338/5000
# 1/1 - 3s - loss: 0.0192 - mae: 0.0192 - mse: 0.0028 - val_loss: 0.1141 - val_mae: 0.1141 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 339/5000
# 1/1 - 2s - loss: 0.0202 - mae: 0.0202 - mse: 0.0028 - val_loss: 0.1154 - val_mae: 0.1154 - val_mse: 0.0236 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 340/5000
# 1/1 - 3s - loss: 0.0195 - mae: 0.0195 - mse: 0.0028 - val_loss: 0.1153 - val_mae: 0.1153 - val_mse: 0.0237 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 341/5000
# 1/1 - 3s - loss: 0.0190 - mae: 0.0190 - mse: 0.0028 - val_loss: 0.1142 - val_mae: 0.1142 - val_mse: 0.0234 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 342/5000
# 1/1 - 2s - loss: 0.0206 - mae: 0.0206 - mse: 0.0028 - val_loss: 0.1145 - val_mae: 0.1145 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 343/5000
# 1/1 - 2s - loss: 0.0188 - mae: 0.0188 - mse: 0.0028 - val_loss: 0.1162 - val_mae: 0.1162 - val_mse: 0.0240 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 344/5000
# 1/1 - 3s - loss: 0.0216 - mae: 0.0216 - mse: 0.0028 - val_loss: 0.1159 - val_mae: 0.1159 - val_mse: 0.0239 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 345/5000
# 1/1 - 2s - loss: 0.0199 - mae: 0.0199 - mse: 0.0028 - val_loss: 0.1144 - val_mae: 0.1144 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 346/5000
# 1/1 - 2s - loss: 0.0217 - mae: 0.0217 - mse: 0.0028 - val_loss: 0.1144 - val_mae: 0.1144 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 347/5000
# 1/1 - 2s - loss: 0.0215 - mae: 0.0215 - mse: 0.0028 - val_loss: 0.1160 - val_mae: 0.1160 - val_mse: 0.0238 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 348/5000
# 1/1 - 3s - loss: 0.0193 - mae: 0.0193 - mse: 0.0028 - val_loss: 0.1162 - val_mae: 0.1162 - val_mse: 0.0239 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 349/5000
# 1/1 - 2s - loss: 0.0199 - mae: 0.0199 - mse: 0.0028 - val_loss: 0.1148 - val_mae: 0.1148 - val_mse: 0.0236 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 350/5000
# 1/1 - 2s - loss: 0.0193 - mae: 0.0193 - mse: 0.0028 - val_loss: 0.1149 - val_mae: 0.1149 - val_mse: 0.0236 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 351/5000
# 1/1 - 2s - loss: 0.0189 - mae: 0.0189 - mse: 0.0027 - val_loss: 0.1164 - val_mae: 0.1164 - val_mse: 0.0240 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 352/5000
# 1/1 - 3s - loss: 0.0197 - mae: 0.0197 - mse: 0.0028 - val_loss: 0.1161 - val_mae: 0.1161 - val_mse: 0.0238 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 353/5000
# 1/1 - 3s - loss: 0.0181 - mae: 0.0181 - mse: 0.0027 - val_loss: 0.1147 - val_mae: 0.1147 - val_mse: 0.0235 - lr: 1.0000e-04 - 3s/epoch - 3s/step
# Epoch 354/5000
# 1/1 - 2s - loss: 0.0211 - mae: 0.0211 - mse: 0.0027 - val_loss: 0.1149 - val_mae: 0.1149 - val_mse: 0.0235 - lr: 1.0000e-04 - 2s/epoch - 2s/step
# Epoch 355/5000
#
# Epoch 00355: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# 1/1 - 3s - loss: 0.0191 - mae: 0.0191 - mse: 0.0027 - val_loss: 0.1166 - val_mae: 0.1166 - val_mse: 0.0241 - lr: 1.0000e-04 - 3s/epoch - 3s/step

# %%
# Learning curves
learning_curves(model_N_BEATS_history)

# %%
# Evaluation model
evaluation_model(model_N_BEATS_history)

# %%
# Evaluate model on test data
model_N_BEATS.evaluate(X_test, y_test)
# Out:
# 7/7 [==============================] - 2s 61ms/step - loss: 0.1076 - mae: 0.1076 - mse: 0.0216
# [0.1076468676328659, 0.1076468676328659, 0.021615685895085335]

# %%
# Make predictions
model_N_BEATS_preds = make_preds(model_N_BEATS, X_test)
model_N_BEATS_preds[:10]
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([0.6333992 , 0.62151206, 0.6619756 , 0.63060844, 0.4408002 ,
#        0.4340851 , 0.43500552, 0.42010653, 0.5081268 , 0.41588613],
#       dtype=float32)>

# %%
# Evaluate predictions
model_N_BEATS_results = evaluate_preds(y_true=y_test,
                                       y_pred=model_N_BEATS_preds)
model_N_BEATS_results
# Out:
# {'mae': 0.10764686,
#  'mape': 19.172869,
#  'mase': 0.8310317,
#  'mse': 0.02161569,
#  'rmse': 0.14702275}

# %%
naive_results
# Out:
# {'mae': 31373.07,
#  'mape': 16.718054,
#  'mase': 0.9957199,
#  'mse': 1794750500.0,
#  'rmse': 42364.496}

# %%
aa=[x for x in range(205)]
plt.figure(figsize=(25, 5))
plt.plot(aa, y_test[:205], marker='.', label="actual")
plt.plot(aa, model_N_BEATS_preds[:205], 'r', label="prediction")
plt.ylabel('Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()

# %% [markdown]
# ### Evaluation of results at another substation
#
# Completely new data for the model.

# %%
# Selection of traction substation
traction_substation_df = data_df.xs('Могоча - Ввод Т1 27.5 кВ', level=1)['consumption']

# Removing duplicate values
traction_substation_df = traction_substation_df.drop_duplicates()

# Selection of the required subset of data
traction_substation_df = traction_substation_df.sort_index(level=[0]).loc['2017-01-01':'2019-12-31']

traction_substation_df.head()
# Out:
# date
# 2017-01-01    149220
# 2017-01-02    138779
# 2017-01-03     24379
# 2017-01-04     45312
# 2017-01-05     37397
# Name: consumption, dtype: int64

# %%
values = traction_substation_df.values

scaler = MinMaxScaler(feature_range=(0, 1))
scaled = scaler.fit_transform(values.reshape(-1, 1))

data_df_norm = series_to_supervised(scaled, n_in=7, n_out=1, dropnan=True)
data_df_norm.shape
# Out:
# (776, 8)

# %%
values = data_df_norm.values

n_train_time = int(len(traction_substation_df)*0.8)

train = values[:n_train_time, :]
test = values[n_train_time:, :]

X_train, y_train = train[:, :-1], train[:, -1]
X_test, y_test = test[:, :-1], test[:, -1]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((626, 7), (150, 7), (626,), (150,))

# %%
# Evaluate model on test data
model_N_BEATS.evaluate(X_test, y_test)
# Out:
# 5/5 [==============================] - 0s 60ms/step - loss: 0.1685 - mae: 0.1685 - mse: 0.0582
# [0.16854196786880493, 0.16854196786880493, 0.05819780379533768]

# %%
# Make predictions
model_N_BEATS_preds = make_preds(model_N_BEATS, X_test)
model_N_BEATS_preds[:10]
# Out:
# <tf.Tensor: shape=(10,), dtype=float32, numpy=
# array([0.7456908 , 0.726361  , 0.8255094 , 0.70085603, 0.782555  ,
#        0.8129562 , 0.83390504, 0.8296449 , 0.8198837 , 0.8038979 ],
#       dtype=float32)>

# %%
# Evaluate predictions
model_N_BEATS_results = evaluate_preds(y_true=y_test,
                                       y_pred=model_N_BEATS_preds)
model_N_BEATS_results
# Out:
# {'mae': 0.16854197,
#  'mape': 3081577.8,
#  'mase': 0.8999557,
#  'mse': 0.058197804,
#  'rmse': 0.24124222}

# %%
naive_results
# Out:
# {'mae': 31373.07,
#  'mape': 16.718054,
#  'mase': 0.9957199,
#  'mse': 1794750500.0,
#  'rmse': 42364.496}

# %%
aa=[x for x in range(150)]
plt.figure(figsize=(25, 5))
plt.plot(aa, y_test[:150], marker='.', label="actual")
plt.plot(aa, model_N_BEATS_preds[:150], 'r', label="prediction")
plt.ylabel('Load', size=15)
plt.xlabel('Time step', size=15)
plt.legend(fontsize=15)
plt.show()
